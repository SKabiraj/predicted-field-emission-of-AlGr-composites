# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def load_data(file_path):
    df = pd.read_excel(file_path)
    return df

# %%
def compute_correlation(df):
    correlation_matrix = df.corr()
    return correlation_matrix

# %%
def plot_heatmap(correlation_matrix):
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title("Feature Correlation Heatmap")
    plt.show()

# %%
def main(file_path):
    df = load_data(file_path)
    correlation_matrix = compute_correlation(df)
    print("Correlation Matrix:\n", correlation_matrix)
    plot_heatmap(correlation_matrix)

# %%
file_path = 'Predicted_AlGr1.5_Compiled data.xlsx'
main(file_path)
# Out:
# Correlation Matrix:
#                                    Time (Minutes)  \
# Time (Minutes)                          1.000000
# Predicted Current (microAmperes)        0.446290
# Current Density                         0.934435
# Electric Field Strength                 1.000000
#
#                                   Predicted Current (microAmperes)  \
# Time (Minutes)                                            0.446290
# Predicted Current (microAmperes)                          1.000000
# Current Density                                           0.445339
# Electric Field Strength                                   0.446290
#
#                                   Current Density  Electric Field Strength
# Time (Minutes)                           0.934435                 1.000000
# Predicted Current (microAmperes)         0.445339                 0.446290
# Current Density                          1.000000                 0.934435
# Electric Field Strength                  0.934435                 1.000000

# %%
df = load_data(file_path)
correlation_matrix = compute_correlation(df)
print("Correlation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                                    Time (Minutes)  \
# Time (Minutes)                          1.000000
# Predicted Current (microAmperes)        0.446290
# Current Density                         0.934435
# Electric Field Strength                 1.000000
#
#                                   Predicted Current (microAmperes)  \
# Time (Minutes)                                            0.446290
# Predicted Current (microAmperes)                          1.000000
# Current Density                                           0.445339
# Electric Field Strength                                   0.446290
#
#                                   Current Density  Electric Field Strength
# Time (Minutes)                           0.934435                 1.000000
# Predicted Current (microAmperes)         0.445339                 0.446290
# Current Density                          1.000000                 0.934435
# Electric Field Strength                  0.934435                 1.000000

# %%
avg_correlation = correlation_matrix.abs().mean().mean()
print("Average Correlation:", avg_correlation)
# Out:
# Average Correlation: 0.7758487108368222
